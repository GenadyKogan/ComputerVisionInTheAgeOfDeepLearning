# %%
import cv2
import sys
import os
import numpy as np
import pandas as pd
from glob import glob

# %%
folder = "hhd_dataset" #sys.argv[1]

# %%
a= glob(folder + "/**/*.png", recursive = True)

# %%
int(a[567].split("\\")[1])
# Out:
# 10

# %%
def add_white_padding(img, color):
        """
        b. A method that adds white padding to the image so that its size is square.
            - If the image width is small from a height, Padding to the right and left should be added.
            - Otherwise, if a width is greater than height, Padding should be added from top to bottom.
        :param img: Image from the dataset
        :param color: The color of the padding to be added
        :return: Image after adding padding
        """
        h, w = img.shape[:2]
        sh, sw = (max(h, w), max(h, w))
        # print(img.shape[:2])
        # interpolation method
        if h > sh or w > sw:  # shrinking image
            interp = cv2.INTER_AREA
        else:  # stretching image
            interp = cv2.INTER_CUBIC
        # aspect ratio of image
        aspect, saspect = float(w) / h, float(sw) / sh

        if (saspect > aspect) or ((saspect == 1) and (aspect <= 1)):  # new horizontal image (width < height)
            new_h = sh
            new_w = np.round(new_h * aspect).astype(int)
            pad_horz = float(sw - new_w) / 2
            pad_left, pad_right = np.floor(pad_horz).astype(int), np.ceil(pad_horz).astype(int)
            pad_top, pad_bot = 0, 0

        elif (saspect < aspect) or ((saspect == 1) and (aspect >= 1)):  # new vertical image (width > height)
            new_w = sw
            new_h = np.round(float(new_w) / aspect).astype(int)
            pad_vert = float(sh - new_h) / 2
            pad_top, pad_bot = np.floor(pad_vert).astype(int), np.ceil(pad_vert).astype(int)
            pad_left, pad_right = 0, 0
        # set pad color
        padColor = color

        # scale and pad
        scaled_img = cv2.resize(img, (new_w, new_h), interpolation=interp)
        scaled_img = cv2.copyMakeBorder(scaled_img, pad_top, pad_bot, pad_left, pad_right,
                                        borderType=cv2.BORDER_CONSTANT, value=padColor)

        # print(scaled_img.shape[:2])
        # cv2.imwrite('scaled_img.jpg', scaled_img)
        # cv2.imshow("image", scaled_img)
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()
        return scaled_img

# %%
def preprocessing(folder):
            # Defining new data frames
            df_data_image = pd.DataFrame(columns=['img_data', 'img_labels', 'dir_path'])
            dir_path = glob(folder + "/**/*.png", recursive = True)
            for img in dir_path:
                # Load image
                input_img = cv2.imread(img)
                # a- Convert image to grayscale
                input_img_cvtColor = cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
                # b. Add white padding to the image so that its size is square
                color = [255, 255, 255]  # white color
                # color = [0,0,0]  # black color
                dst = add_white_padding(input_img_cvtColor, color)
                # c- Resize the image to a uniform size (32,32)
                input_img_resize = cv2.resize(dst, (32, 32))
                # # Append all the data to dataframe
                df_data_image = df_data_image.append(
                    {'img_data': input_img_resize, 'img_labels':int(img.split("\\")[-2]), 'dir_path': img},
                    ignore_index=True)
                df_data_image['img_labels']= df_data_image['img_labels'].astype(int)
            return df_data_image

# %%
df_data_image= preprocessing(folder)

# %%
df_data_image
# Out:
#                                                img_data  img_labels  \
# 0     [[255, 255, 255, 255, 255, 255, 255, 255, 245,...           0
# 1     [[255, 255, 255, 255, 255, 255, 255, 255, 255,...           0
# 2     [[250, 251, 253, 252, 253, 251, 250, 252, 252,...           0
# 3     [[255, 252, 242, 252, 252, 249, 254, 253, 255,...           0
# 4     [[252, 254, 247, 247, 250, 254, 253, 251, 246,...           0
# ...                                                 ...         ...
# 5068  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...           9
# 5069  [[255, 255, 255, 255, 254, 254, 254, 254, 253,...           9
# 5070  [[255, 255, 255, 255, 255, 255, 252, 253, 253,...           9
# 5071  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...           9
# 5072  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...           9
#
#                      dir_path
# 0       hhd_dataset\0\0_1.png
# 1      hhd_dataset\0\0_10.png
# 2     hhd_dataset\0\0_100.png
# 3     hhd_dataset\0\0_101.png
# 4     hhd_dataset\0\0_102.png
# ...                       ...
# 5068   hhd_dataset\9\9_95.png
# 5069   hhd_dataset\9\9_96.png
# 5070   hhd_dataset\9\9_97.png
# 5071   hhd_dataset\9\9_98.png
# 5072   hhd_dataset\9\9_99.png
#
# [5073 rows x 3 columns]

# %%
import cv2
import sys
import os
import numpy as np
import pandas as pd
def add_white_padding(img, color):
        """
        b. A method that adds white padding to the image so that its size is square.
            - If the image width is small from a height, Padding to the right and left should be added.
            - Otherwise, if a width is greater than height, Padding should be added from top to bottom.
        :param img: Image from the dataset
        :param color: The color of the padding to be added
        :return: Image after adding padding
        """
        h, w = img.shape[:2]
        sh, sw = (max(h, w), max(h, w))
        # print(img.shape[:2])
        # interpolation method
        if h > sh or w > sw:  # shrinking image
            interp = cv2.INTER_AREA
        else:  # stretching image
            interp = cv2.INTER_CUBIC
        # aspect ratio of image
        aspect, saspect = float(w) / h, float(sw) / sh

        if (saspect > aspect) or ((saspect == 1) and (aspect <= 1)):  # new horizontal image (width < height)
            new_h = sh
            new_w = np.round(new_h * aspect).astype(int)
            pad_horz = float(sw - new_w) / 2
            pad_left, pad_right = np.floor(pad_horz).astype(int), np.ceil(pad_horz).astype(int)
            pad_top, pad_bot = 0, 0

        elif (saspect < aspect) or ((saspect == 1) and (aspect >= 1)):  # new vertical image (width > height)
            new_w = sw
            new_h = np.round(float(new_w) / aspect).astype(int)
            pad_vert = float(sh - new_h) / 2
            pad_top, pad_bot = np.floor(pad_vert).astype(int), np.ceil(pad_vert).astype(int)
            pad_left, pad_right = 0, 0
        # set pad color
        padColor = color

        # scale and pad
        scaled_img = cv2.resize(img, (new_w, new_h), interpolation=interp)
        scaled_img = cv2.copyMakeBorder(scaled_img, pad_top, pad_bot, pad_left, pad_right,
                                        borderType=cv2.BORDER_CONSTANT, value=padColor)

        # print(scaled_img.shape[:2])
        # cv2.imwrite('scaled_img.jpg', scaled_img)
        # cv2.imshow("image", scaled_img)
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()
        return scaled_img

def preprocessing(folder):

        folder_content = os.listdir(folder)
        # Defining new data frames
        df_data_image = pd.DataFrame(columns=['img_data', 'img_labels', 'image_name'])

        for dataset in folder_content:
            img_list = os.listdir(folder + '/' + dataset)
            print('Loaded the images of dataset-' + '{}\n'.format(dataset))

            for img in img_list:
                # Load image
                input_img = cv2.imread(folder + '/' + dataset + '/' + img)
                # a- Convert image to grayscale
                input_img_cvtColor = cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
                # b. Add white padding to the image so that its size is square
                color = [255, 255, 255]  # white color
                # color = [0,0,0]  # black color
                dst = add_white_padding(input_img_cvtColor, color)
                # c- Resize the image to a uniform size (32,32)
                input_img_resize = cv2.resize(dst, (32, 32))

                # # Append all the data to dataframe
                df_data_image = df_data_image.append(
                    {'img_data': input_img_resize, 'img_labels': int(dataset), 'image_name': img},
                    ignore_index=True)

        return df_data_image

# %%
folder = "hhd_dataset" #sys.argv[1]
df_data_image= preprocessing(folder)
# Out:
# Loaded the images of dataset-0
#
# Loaded the images of dataset-1
#
# Loaded the images of dataset-10
#
# Loaded the images of dataset-11
#
# Loaded the images of dataset-12
#
# Loaded the images of dataset-13
#
# Loaded the images of dataset-14
#
# Loaded the images of dataset-15
#
# Loaded the images of dataset-16
#
# Loaded the images of dataset-17
#
# Loaded the images of dataset-18
#
# Loaded the images of dataset-19
#
# Loaded the images of dataset-2
#
# Loaded the images of dataset-20
#
# Loaded the images of dataset-21
#
# Loaded the images of dataset-22
#
# Loaded the images of dataset-23
#
# Loaded the images of dataset-24
#
# Loaded the images of dataset-25
#
# Loaded the images of dataset-26
#
# Loaded the images of dataset-3
#
# Loaded the images of dataset-4
#
# Loaded the images of dataset-5
#
# Loaded the images of dataset-6
#
# Loaded the images of dataset-7
#
# Loaded the images of dataset-8
#
# Loaded the images of dataset-9

# %%
folder_content = os.listdir(folder)
# Defining new data frames
df_data_image = pd.DataFrame(columns=['img_data', 'img_labels', 'image_name'])
df_data_image['image_name'] = sum([os.listdir(folder + '/' + dataset) for dataset in folder_content],[])
df_data_image['img_labels'] = list(map(lambda x: x.split("_")[0], df_data_image['image_name'].values.tolist()))

# %%
input_img = cv2.imread("1_148.png")
input_img2 = cv2.imread("1_192.png")
# a- Convert image to grayscale
input_img_cvtColor = cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
cv2.imshow("image", input_img_cvtColor)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
input_img2.shape
# Out:
# (101, 59, 3)

# %%
# b. Add white padding to the image so that its size is square
color = [0,0,0] #black color
dst = add_white_padding(input_img2, color)
cv2.imshow("image", dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(dst.shape)
# Out:
# (80, 80)

# %%
# c- Resize the image to a uniform size (32,32)
input_img_resize = cv2.resize(dst, (32, 32))
print(input_img_resize.shape)
# Out:
# (32, 32)

# %%
df_data_image['img_labels'].value_counts()
# Out:
# 24    216
# 12    195
# 0     194
# 9     194
# 23    194
# 15    194
# 1     194
# 10    194
# 13    194
# 8     194
# 6     194
# 5     194
# 2     194
# 3     194
# 7     194
# 4     193
# 19    193
# 17    192
# 21    190
# 25    190
# 26    187
# 18    179
# 20    167
# 16    166
# 14    164
# 22    163
# 11    156
# Name: img_labels, dtype: int64

# %%
train = pd.DataFrame(columns=['img_data', 'img_labels', 'image_name'])

# %%
df = df_data_image

# %%
train=[df[df['img_labels']==label].sample(frac=0.8) for label in set(df['img_labels'])]

# %%
train
# Out:
# [                                              img_data img_labels image_name
#  72   [[255, 255, 255, 250, 255, 250, 254, 254, 249,...          0  0_197.png
#  175  [[255, 255, 255, 255, 255, 253, 254, 254, 253,...          0   0_82.png
#  55   [[255, 255, 255, 255, 255, 255, 255, 255, 255,...
[[255, 255, 255, 255, 255, 255, 255, 255, 255,...         23   23_48.png
#  3101  [[255, 255, 255, 255, 255, 255, 255, 254, 254,...         23    23_8.png
#  3094  [[255, 255, 255, 255, 255, 255, 255, 254, 254,...         23   23_73.png
#  3051  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         23   23_34.png
#
#  [155 rows x 3 columns],
#                                                 img_data img_labels  image_name
#  3315  [[255, 255, 255, 251, 254, 255, 254, 254, 254,...         24   24_78.png
#  3288  [[254, 254, 253, 252, 251, 253, 247, 252, 249,...         24   24_53.png
#  3215  [[254, 254, 254, 254, 254, 254, 254, 254, 254,...         24  24_192.png
#  3306  [[255, 255, 255, 255, 251, 253, 252, 253, 253,...         24    24_7.png
#  3253  [[255, 255, 253, 254, 254, 254, 254, 254, 254,...         24  24_226.png
#  ...                                                 ...        ...         ...
#  3242  [[255, 255, 255, 255, 254, 254, 253, 251, 252,...         24  24_216.png
#  3248  [[254, 254, 254, 254, 254, 254, 254, 253, 254,...         24  24_221.png
#  3279  [[255, 252, 255, 251, 250, 254, 254, 254, 254,...         24   24_45.png
#  3300  [[255, 255, 251, 252, 255, 252, 254, 254, 254,...         24   24_64.png
#  3235  [[255, 255, 255, 252, 252, 254, 254, 253, 247,...         24   24_21.png
#
#  [173 rows x 3 columns],
#                                                 img_data img_labels  image_name
#  3523  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         25   25_94.png
#  3464  [[255, 255, 255, 255, 255, 255, 255, 255, 254,...         25   25_40.png
#  3454  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         25   25_31.png
#  3402  [[255, 255, 254, 255, 254, 252, 254, 254, 254,...         25  25_189.png
#  3473  [[255, 252, 255, 254, 252, 252, 253, 254, 252,...         25   25_49.png
#  ...                                                 ...        ...         ...
#  3492  [[255, 255, 255, 255, 254, 253, 255, 253, 251,...         25   25_66.png
#  3444  [[255, 255, 255, 255, 255, 254, 254, 254, 254,...         25  25_226.png
#  3443  [[255, 255, 255, 255, 255, 255, 255, 0, 255, 2...         25  25_225.png
#  3389  [[255, 255, 255, 255, 255, 254, 254, 254, 250,...         25  25_144.png
#  3386  [[255, 255, 255, 255, 255, 255, 254, 254, 255,...         25  25_141.png
#
#  [152 rows x 3 columns],
#                                                 img_data img_labels  image_name
#  3587  [[255, 255, 254, 254, 254, 254, 253, 254, 254,...         26  26_184.png
#  3542  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         26  26_110.png
#  3601  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         26  26_197.png
#  3530  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         26   26_10.png
#  3697  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         26   26_82.png
#  ...                                                 ...        ...         ...
#  3691  [[255, 255, 255, 255, 255, 255, 255, 255, 0, 2...         26   26_77.png
#  3604  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         26    26_2.png
#  3580  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         26   26_16.png
#  3557  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...         26  26_124.png
#  3558  [[255, 255, 255, 255, 255, 254, 254, 254, 254,...         26  26_125.png
#
#  [150 rows x 3 columns]]

# %%
def split_dataset(df):
    # Defining new data frames for all train, val, test
    all_train = pd.DataFrame(columns=['img_data', 'img_labels'])
    all_val, all_test = all_train, all_train
    # A loop that runs on all types of labels (0-26) and divides each label to 80% train, 10% val and 10% test
    for label in set(df['img_labels']):
        #Take 80% of the data on a particular label to train
        train=df[df['img_labels']==label].sample(frac=0.8)
        # not_train - Contains 20% data that are not train
        not_train=df[df['img_labels']==label].drop(train.index)
        # Of the remaining 20%, half go to val and half to test
        val= not_train.sample(frac=0.5) 
        test=not_train.drop(val.index)
        # Append all the data to dataframes
        all_train, all_val, all_test = all_train.append(train), all_val.append(val), all_test.append(test)
    return all_train, all_val, all_test

# %%
all_train, all_val, all_test= split_dataset(df_data_image)

# %%
all_train.shape
# Out:
# (4057, 3)

# %%
all_train
# Out:
#                                                img_data img_labels  \
# 1208  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...          1
# 1292  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...          1
# 1481  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...          1
# 1780  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...          1
# 980   [[255, 178, 175, 228, 254, 254, 254, 254, 254,...          1
# ...                                                 ...        ...
# 2259  [[255, 255, 255, 255, 255, 254, 254, 254, 254,...          2
# 3677  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...          2
# 3435  [[254, 254, 254, 254, 254, 254, 254, 252, 254,...          2
# 3243  [[255, 255, 255, 255, 254, 251, 250, 254, 254,...          2
# 3025  [[255, 255, 255, 255, 255, 255, 254, 254, 254,...          2
#
#                        dir_path
# 1208   hhd_dataset\14\14_24.png
# 1292   hhd_dataset\15\15_10.png
# 1481   hhd_dataset\15\15_96.png
# 1780   hhd_dataset\17\17_42.png
# 980   hhd_dataset\13\13_141.png
# ...                         ...
# 2259    hhd_dataset\2\2_139.png
# 3677   hhd_dataset\26\26_64.png
# 3435  hhd_dataset\25\25_218.png
# 3243  hhd_dataset\24\24_217.png
# 3025  hhd_dataset\23\23_218.png
#
# [4057 rows x 3 columns]

# %%
df_data_image[df_data_image['img_labels'] == 2]
# Out:
#                                                img_data img_labels image_name
# 2215  [[255, 255, 255, 255, 255, 255, 255, 254, 254,...          2    2_1.png
# 2216  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...          2   2_10.png
# 2217  [[255, 255, 255, 254, 252, 252, 252, 252, 254,...          2  2_100.png
# 2218  [[254, 252, 249, 246, 245, 245, 245, 245, 241,...          2  2_101.png
# 2219  [[255, 255, 255, 255, 255, 255, 254, 254, 254,...          2  2_102.png
# ...                                                 ...        ...        ...
# 2404  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...          2   2_95.png
# 2405  [[255, 255, 255, 255, 254, 254, 254, 254, 254,...          2   2_96.png
# 2406  [[255, 255, 255, 255, 255, 255, 255, 251, 247,...          2   2_97.png
# 2407  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...          2   2_98.png
# 2408  [[255, 254, 254, 252, 255, 255, 254, 255, 255,...          2   2_99.png
#
# [194 rows x 3 columns]

# %%
    def dataset_to_npArray(df):
        # Convert a dataset to np.array
        img_data = np.array(df['img_data'].values.tolist())
        # Size after reshape is (img_data.shape[0], 32*32)
        # (40000, 32, 32)
        X = img_data.reshape(img_data.shape[0], -1)
        y = np.array(df['img_labels'].values.tolist())
        return X, y

# %%
        x_train, y_train = dataset_to_npArray(all_train)
        x_val, y_val = dataset_to_npArray(all_val)
        x_test, y_test = dataset_to_npArray(all_test)

# %%
y_train.shape
# Out:
# (4056,)

# %%
x_train.shape
# Out:
# (4056, 1024)

# %%
import cv2, sys, os
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
        # Setup arrays to store train and test accuracies
        neighbors, error_rate = np.arange(1, 16, 2), []
        train_accuracy, val_accuracy = np.empty(len(neighbors)), np.empty(len(neighbors))
        # Enum Loop, accuracy results using range on 'n' values for KNN Classifier
        for acc, n in enumerate(neighbors):
            # Try KNeighbors with each of 'n' neighbors
            knn = KNeighborsClassifier(n_neighbors=n, weights='distance', metric='euclidean')
            # Fitting
            knn.fit(x_train, y_train)
            # Training Accuracy
            train_accuracy[acc] = knn.score(x_train, y_train)
            # Val Accuracy
            val_accuracy[acc] = knn.score(x_val, y_val)
            predict_i = knn.predict(x_val)
            error_rate.append(np.mean(predict_i != y_val))
        print("error_rate:",error_rate)
        print("\ntrain_accuracy: ", train_accuracy)
        print("\nval_accuracy: ", val_accuracy)
# Out:
# error_rate: [0.4155339805825243, 0.39223300970873787, 0.4, 0.3941747572815534, 0.40194174757281553, 0.39611650485436894, 0.4, 0.40194174757281553]
#
# train_accuracy:  [1. 1. 1. 1. 1. 1. 1. 1.]
#
# val_accuracy:  [0.58446602 0.60776699 0.6        0.60582524 0.59805825 0.6038835
#  0.6        0.59805825]

# %%
        df1= pd.DataFrame(columns=['k','test_acc','train_acc','error_rate'])
        # Enum Loop, accuracy results using range on 'n' values for KNN Classifier
        for n in range(1,16,2):
            # Try KNeighbors with each of 'n' neighbors
            knn = KNeighborsClassifier(n_neighbors=n, weights='distance', metric='euclidean')
            # Fitting
            knn.fit(x_train, y_train)
            # Val Accuracy
            test_acc = knn.score(x_val, y_val)
            # Training Accuracy
            train_acc = knn.score(x_train, y_train)
            
            predict_i = knn.predict(x_val)
            error_rate=np.mean(predict_i != y_val)
            
            df1.loc[n]= [n,test_acc, train_acc, error_rate]

# %%
df1
# Out:
#        k  test_acc  train_acc  error_rate
# 1    1.0  0.619417        1.0    0.380583
# 3    3.0  0.648544        1.0    0.351456
# 5    5.0  0.640777        1.0    0.359223
# 7    7.0  0.642718        1.0    0.357282
# 9    9.0  0.633010        1.0    0.366990
# 11  11.0  0.634951        1.0    0.365049
# 13  13.0  0.629126        1.0    0.370874
# 15  15.0  0.625243        1.0    0.374757

# %%
def get_results_for_specific_k(k, x_train, y_train, x_val, y_val ):
            # Try KNeighbors with each of 'n' neighbors
            knn = KNeighborsClassifier(n_neighbors=k, weights='distance', metric='euclidean')
            # Fitting
            knn.fit(x_train, y_train)
            # Val Accuracy
            test_acc = knn.score(x_val, y_val)
            # Training Accuracy
            train_acc = knn.score(x_train, y_train)
            
            predict_i = knn.predict(x_val)
            error_rate=np.mean(predict_i != y_val)
            #dict_ = {'k1': [k],'test_acc': [test_acc],'train_acc': [train_acc],'error_rate':[error_rate]}
            return [k, test_acc, train_acc,error_rate ]

# %%
df_result_beast_k = pd.DataFrame(range(1, 16, 2), columns = ['k'])

# %%
df_result_beast_k
# Out:
#     k
# 0   1
# 1   3
# 2   5
# 3   7
# 4   9
# 5  11
# 6  13
# 7  15

# %%
df_result_beast_k = df_result_beast_k['k'].apply(lambda r: pd.Series(get_results_for_specific_k(r,x_train, y_train, x_val, y_val), 
                                                                     index = ['k','val_acc','train_acc','error_rate']))

# %%
df_result_beast_k
# Out:
#       k   val_acc  train_acc  error_rate
# 0   1.0  0.601942        1.0    0.398058
# 1   3.0  0.617476        1.0    0.382524
# 2   5.0  0.617476        1.0    0.382524
# 3   7.0  0.611650        1.0    0.388350
# 4   9.0  0.609709        1.0    0.390291
# 5  11.0  0.592233        1.0    0.407767
# 6  13.0  0.584466        1.0    0.415534
# 7  15.0  0.596117        1.0    0.403883
